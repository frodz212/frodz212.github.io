# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ppg2008.csv')
df = df.set_index('Name  ')

# %%
sns.heatmap(df)
plt.title('Heatmap Python')
# Out:
# Text(0.5, 1.0, 'Heatmap Python')

# %%
data = pd.read_csv('costcos-geocoded.csv')

# %%
# import the library
import folium

# Make an empty map
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# add marker one by one on the map
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['Latitude'], data.iloc[i]['Longitude']],
      popup=data.iloc[i]['City'],
   ).add_to(m)

# Show the map again
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a976898944681c73a7bfb04b3b178be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a976898944681c73a7bfb04b3b178be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a976898944681c73a7bfb04b3b178be = L.map(
#                 &quot;map_7a976898944681c73a7bfb04b3b178be&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32df98969f5fe4f8e77db22a28555229 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_32df98969f5fe4f8e77db22a28555229.addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#             var marker_0f540eee666d8cb4d4f712f4173c714b = L.marker(
#                 [34.7430949, -86.6009553],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_43768906d94af16c2a941c0075631c61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9639affc391b7089c9ba5cdbc069507 = $(`&lt;div id=&quot;html_f9639affc391b7089c9ba5cdbc069507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Huntsville&lt;/div&gt;`)[0];
#                 popup_43768906d94af16c2a941c0075631c61.setContent(html_f9639affc391b7089c9ba5cdbc069507);
#
#
#
#         marker_0f540eee666d8cb4d4f712f4173c714b.bindPopup(popup_43768906d94af16c2a941c0075631c61)
#         ;
#
#
#
#
#             var marker_03ac0122b06626c1e0583e960f0fb192 = L.marker(
#                 [33.377649, -86.81242],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_d1eb725292bdcdb8a1c3a548c0a6143c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6727fd488a9be2e1d54de60216ea91ab = $(`&lt;div id=&quot;html_6727fd488a9be2e1d54de60216ea91ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hoover&lt;/div&gt;`)[0];
#                 popup_d1eb725292bdcdb8a1c3a548c0a6143c.setContent(html_6727fd488a9be2e1d54de60216ea91ab);
#
#
#
#         marker_03ac0122b06626c1e0583e960f0fb192.bindPopup(popup_d1eb725292bdcdb8a1c3a548c0a6143c)
#         ;
#
#
#
#
#             var marker_1289cc415815de182fbdd3eb7e9fea51 = L.marker(
#                 [32.363889, -86.150884],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_466add0774bdd40be9074106619bc2de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ded0f84afa33163638c418dbbfd86bd = $(`&lt;div id=&quot;html_0ded0f84afa33163638c418dbbfd86bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Montgomery&lt;/div&gt;`)[0];
#                 popup_466add0774bdd40be9074106619bc2de.setContent(html_0ded0f84afa33163638c418dbbfd86bd);
#
#
#
#         marker_1289cc415815de182fbdd3eb7e9fea51.bindPopup(popup_466add0774bdd40be9074106619bc2de)
#         ;
#
#
#
#
#             var marker_d02e2e1eb7f377d1f5c9bb909aa44b9e = L.marker(
#                 [58.3592, -134.483],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_41082f09c42f0c1e217d693f02a9e564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a8806249aed6f0ac2ad6f3773047d42f = $(`&lt;div id=&quot;html_a8806249aed6f0ac2ad6f3773047d42f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Juneau&lt;/div&gt;`)[0];
#                 popup_41082f09c42f0c1e217d693f02a9e564.setContent(html_a8806249aed6f0ac2ad6f3773047d42f);
#
#
#
#         marker_d02e2e1eb7f377d1f5c9bb909aa44b9e.bindPopup(popup_41082f09c42f0c1e217d693f02a9e564)
#         ;
#
#
#
#
#             var marker_8d3e9f1576e870a9363507616a0523dd = L.marker(
#                 [61.143266, -149.884217],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_d9f2319aee4af3c1ffa4eab768cef0e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_012d3b6669fa6d9abcd0be4c654a29dd = $(`&lt;div id=&quot;html_012d3b6669fa6d9abcd0be4c654a29dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Anchorage&lt;/div&gt;`)[0];
#                 popup_d9f2319aee4af3c1ffa4eab768cef0e0.setContent(html_012d3b6669fa6d9abcd0be4c654a29dd);
#
#
#
#         marker_8d3e9f1576e870a9363507616a0523dd.bindPopup(popup_d9f2319aee4af3c1ffa4eab768cef0e0)
#         ;
#
#
#
#
#             var marker_0983254b9606a8a36c83ef7582c5b82b = L.marker(
#                 [61.210815, -149.804337],
#                 {}
#             ).addTo(map_7a976898944681c73a7bfb04b3b178be);
#
#
#         var popup_f5785

# %%
df = df.reset_index()

# %%
# stem function
plt.stem(df['Name  '], df['G'])
plt.xticks(rotation=90)
plt.title('Lollipop Plot Python')
plt.show()
